# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

from newsapi.newsapi_client import NewsApiClient
# %matplotlib inline

# %%
# Read your api key environment variable
# YOUR CODE HERE!
load_dotenv()
api_key=os.getenv("NEWS_API_KEY")

# %%
# Create a newsapi client
# YOUR CODE HERE!
newsapi = NewsApiClient(api_key = api_key)

# %%
# Fetch the Bitcoin news articles
# YOUR CODE HERE!
bitcoin_articles = newsapi.get_everything(q='Bitcoin',
                                      language='en',
                                      sort_by='relevancy',
                                      page_size=100)
bitcoin_articles['articles'][0]
# Out:
# {'source': {'id': None, 'name': 'Lifehacker.com'},
#  'author': 'David Murphy',
#  'title': 'What You Need to Know About Buying Cryptocurrency on PayPal',
#  'description': 'Whether you’re looking to make a larger investment or you just want to dabble in cryptocurrencies, you can purchase Bitcoin, Ethereum, Bitcoin Cash, and Litecoin through PayPal. And, soon, you’ll be able to pay various merchants using your cryptocurrency stas…',
#  'url': 'https://lifehacker.com/what-you-need-to-know-about-buying-cryptocurrency-on-pa-1846585705',
#  'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/qvc2foo4ufow1cbsuk9f.jpg',
#  'publishedAt': '2021-03-31T14:00:00Z',
#  'content': 'Whether youre looking to make a larger investment or you just want to dabble in cryptocurrencies, you can purchase Bitcoin, Ethereum, Bitcoin Cash, and Litecoin through PayPal. And, soon, youll be ab… [+3818 chars]'}

# %%
# Fetch the Ethereum news articles
# YOUR CODE HERE!
ethereum_articles = newsapi.get_everything(q='Ethereum',
                                      language='en',
                                      sort_by='relevancy',
                                      page_size=100)
ethereum_articles['articles'][0]
# Out:
# {'source': {'id': 'the-verge', 'name': 'The Verge'},
#  'author': 'Adi Robertson',
#  'title': 'India will reportedly introduce bill to make owning cryptocurrency illegal',
#  'description': 'India’s legislature is reportedly considering a near-total ban on private cryptocurrencies like Bitcoin or Ethereum, including owning the virtual currency. The government has discussed plans for a national digital currency as an alternative.',
#  'url': 'https://www.theverge.com/2021/3/15/22332677/india-cryptocurrency-trading-mining-possession-ban-law-report',
#  'urlToImage': 'https://cdn.vox-cdn.com/thumbor/IdgNJaOIQBsN8QbQcH2MDU6sAUA=/0x243:2040x1311/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/10432811/mdoying_180308_2373_0091still.jpg',
#  'publishedAt': '2021-03-15T22:25:02Z',
#  'content': 'One of the strictest crackdowns worldwide\r\nPhoto by Michele Doying / The Verge\r\nIndia is reportedly moving forward with a sweeping ban on cryptocurrencies. According to Reuters, the countrys legislat… [+1656 chars]'}

# %%
# Create the Bitcoin sentiment scores DataFrame
# YOUR CODE HERE!
bitcoin_sentiments = []
for article in bitcoin_articles['articles']:
    try: 
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
    except AttributeError:
        pass

bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["compound", "positive", "negative", "neutral", "text"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#    compound  positive  negative  neutral  \
# 0    0.0772     0.039       0.0    0.961
# 1    0.5859     0.127       0.0    0.873
# 2    0.6124     0.135       0.0    0.865
# 3    0.3182     0.065       0.0    0.935
# 4    0.2023     0.050       0.0    0.950
#
#                                                 text
# 0  Whether youre looking to make a larger investm...
# 1  As it promised earlier this year, Tesla now ac...
# 2  The crypto industry as a whole has seen a mome...
# 3  The inevitable has happened: You can now purch...
# 4  Tesla made headlines earlier this year when it...

# %%
# Create the ethereum sentiment scores DataFrame
# YOUR CODE HERE!
ethereum_sentiments = []
for article in ethereum_articles['articles']:
    try: 
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
    except AttributeError:
        pass

ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["compound", "positive", "negative", "neutral", "text"]
ethereum_df = ethereum_df[cols]

ethereum_df.head()
# Out:
#    compound  positive  negative  neutral  \
# 0   -0.5574     0.000      0.11    0.890
# 1    0.0772     0.039      0.00    0.961
# 2    0.0000     0.000      0.00    1.000
# 3    0.0000     0.000      0.00    1.000
# 4    0.2732     0.062      0.00    0.938
#
#                                                 text
# 0  One of the strictest crackdowns worldwide\r\nP...
# 1  Whether youre looking to make a larger investm...
# 2  Famed auction house Christies just sold its fi...
# 3  Payment card network Visa has announced that t...
# 4  ConsenSys, a key player in crypto and a major ...

# %%
# Describe the Bitcoin Sentiment
# YOUR CODE HERE!
bitcoin_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.135380    0.055780    0.022870    0.921350
# std      0.354966    0.067605    0.045033    0.081106
# min     -0.757900    0.000000    0.000000    0.660000
# 25%      0.000000    0.000000    0.000000    0.869500
# 50%      0.000000    0.042500    0.000000    0.933500
# 75%      0.366350    0.085000    0.009500    1.000000
# max      0.908000    0.340000    0.198000    1.000000

# %%
# Describe the Ethereum Sentiment
# YOUR CODE HERE!
ethereum_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.134765    0.065420    0.028170    0.906430
# std      0.395316    0.075469    0.044324    0.084787
# min     -0.659700    0.000000    0.000000    0.664000
# 25%      0.000000    0.000000    0.000000    0.846750
# 50%      0.000000    0.047500    0.000000    0.920000
# 75%      0.458800    0.107000    0.061000    1.000000
# max      0.885800    0.273000    0.166000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
from nltk.corpus import stopwords
import re
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\william\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\william\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\william\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Expand the default stopwords list if necessary
# YOUR CODE HERE!
sw = set(stopwords.words('english'))
print(sw)

sw_expand = {'youre', 'ha', 'whether'}
# Out:
# {'all', 'itself', 'was', "hadn't", 'haven', 'at', 'been', 'more', 'd', "mustn't", 'if', 'off', 'my', 'didn', 'other', 'these', 'about', 'her', 'against', 'wouldn', "shouldn't", 'the', 'we', 'himself', 'before', 'any', "should've", 'now', 'you', 'them', 'only', 'yours', "shan't", "wasn't", 'then', 'shan', 'm', 'will', 'ours', 'up', 'nor', 'so', 'same', 'had', 'whom', 'having', 'him', "wouldn't", 'isn', 'for', 'how', 'few', "aren't", 'weren', 'has', 'hadn', 'that', 'won', 'as', 'did', "isn't", 'it', "you've", 'what', 'out', 'hasn', 'am', 't', 'by', 'our', 's', 'y', 'during', 'does', 'just', 'mightn', 'needn', 'i', 'this', 'over', 'aren', 'while', 'll', 'both', 'wasn', "needn't", 'me', 'they', 'who', 'on', 'doesn', 'can', 'once', 'ain', 'no', "won't", 'being', 'yourselves', 'in', 'most', "didn't", 'she', 'such', 'with', 'shouldn', "weren't", 'after', "hasn't", 'down', "doesn't", 'and', 'should', 'is', 'between', 'he', 'into', 'do', 'to', 'some', 'because', 'don', 'yourself', 'too', 'through', 'own', 'when', 'ourselves', 'further', 'below', "she's", 'its', "it's", 'where', 'were', "you'll", 'ma', 'there', "you're", 'themselves', 'theirs', "couldn't", 'than', 'their', 'be', 'again', 'but', 'here', "you'd", 'couldn', 'an', 'or', 'of', 'have', 'o', 're', 'above', "don't", 'why', 'very', 'those', 'doing', 'myself', 'not', 'under', 'his', "mightn't", 'which', "that'll", 'from', 'until', 'each', 'mustn', 'a', 'your', "haven't", 'herself', 'are', 've', 'hers'}

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Create a list of the words
    sw = set(stopwords.words('english'))
    # Convert the words to lowercase
    regex = re.compile('[^a-zA-Z]')
    # Remove the punctuation
    re_clean = regex.sub(' ', text)
    # Remove the stop words
    words = word_tokenize(re_clean)
    # Lemmatize Words into root words
    lemmatizer = WordNetLemmatizer()
    lem = [lemmatizer.lemmatize(word) for word in words]
    tokens = [word.lower() for word in lem if word.lower() not in sw.union(sw_expand)]
    
    return tokens

# %%
# Create a new tokens column for bitcoin
# YOUR CODE HERE!


bitcoin_df['tokens'] = bitcoin_df['text'].apply(tokenizer)
bitcoin_df.head()
# Out:
#    compound  positive  negative  neutral  \
# 0    0.0772     0.039       0.0    0.961
# 1    0.5859     0.127       0.0    0.873
# 2    0.6124     0.135       0.0    0.865
# 3    0.3182     0.065       0.0    0.935
# 4    0.2023     0.050       0.0    0.950
#
#                                                 text  \
# 0  Whether youre looking to make a larger investm...
# 1  As it promised earlier this year, Tesla now ac...
# 2  The crypto industry as a whole has seen a mome...
# 3  The inevitable has happened: You can now purch...
# 4  Tesla made headlines earlier this year when it...
#
#                                               tokens
# 0  [looking, make, larger, investment, want, dabb...
# 1  [promised, earlier, year, tesla, accepts, paym...
# 2  [crypto, industry, whole, seen, momentous, yea...
# 3  [inevitable, happened, purchase, tesla, vehicl...
# 4  [tesla, made, headline, earlier, year, took, s...

# %%
# Create a new tokens column for ethereum
# YOUR CODE HERE!
ethereum_df['tokens'] = ethereum_df['text'].apply(tokenizer)
ethereum_df.head()
# Out:
#    compound  positive  negative  neutral  \
# 0   -0.5574     0.000      0.11    0.890
# 1    0.0772     0.039      0.00    0.961
# 2    0.0000     0.000      0.00    1.000
# 3    0.0000     0.000      0.00    1.000
# 4    0.2732     0.062      0.00    0.938
#
#                                                 text  \
# 0  One of the strictest crackdowns worldwide\r\nP...
# 1  Whether youre looking to make a larger investm...
# 2  Famed auction house Christies just sold its fi...
# 3  Payment card network Visa has announced that t...
# 4  ConsenSys, a key player in crypto and a major ...
#
#                                               tokens
# 0  [one, strictest, crackdown, worldwide, photo, ...
# 1  [looking, make, larger, investment, want, dabb...
# 2  [famed, auction, house, christies, sold, first...
# 3  [payment, card, network, visa, announced, tran...
# 4  [consensys, key, player, crypto, major, propon...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
# YOUR CODE HERE!
bitcoin_text = []
for token in bitcoin_df['tokens']:
    for text in token:
        bitcoin_text.append(text)
bitcoin_counts = Counter(ngrams(bitcoin_text, n=2))
bitcoin_counts.most_common(20)
# Out:
# [(('char', 'reuters'), 24),
#  (('reuters', 'staff'), 23),
#  (('file', 'photo'), 17),
#  (('staff', 'file'), 13),
#  (('elon', 'musk'), 11),
#  (('virtual', 'currency'), 11),
#  (('char', 'march'), 9),
#  (('illustration', 'taken'), 9),
#  (('march', 'reuters'), 8),
#  (('march', 'min'), 7),
#  (('min', 'read'), 7),
#  (('currency', 'bitcoin'), 7),
#  (('reuters', 'dado'), 7),
#  (('dado', 'ruvic'), 7),
#  (('london', 'reuters'), 7),
#  (('representation', 'virtual'), 6),
#  (('ruvic', 'illustration'), 6),
#  (('new', 'york'), 6),
#  (('char', 'london'), 6),
#  (('non', 'fungible'), 5)]

# %%
# Generate the Ethereum N-grams where N=2
# YOUR CODE HERE!
ethereum_text = []
for token in ethereum_df['tokens']:
    for text in token:
        ethereum_text.append(text)
ethereum_counts = Counter(ngrams(ethereum_text, n=2))
ethereum_counts.most_common(20)
# Out:
# [(('non', 'fungible'), 16),
#  (('fungible', 'token'), 16),
#  (('char', 'march'), 8),
#  (('min', 'read'), 7),
#  (('token', 'nfts'), 7),
#  (('ethereum', 'blockchain'), 6),
#  (('march', 'min'), 6),
#  (('last', 'month'), 6),
#  (('allow', 'use'), 5),
#  (('digital', 'currency'), 5),
#  (('token', 'nft'), 5),
#  (('usd', 'coin'), 4),
#  (('raised', 'million'), 4),
#  (('cryptocurrency', 'ether'), 4),
#  (('char', 'reuters'), 4),
#  (('reuters', 'visa'), 4),
#  (('use', 'cryptocurrency'), 4),
#  (('opinions', 'expressed'), 4),
#  (('expressed', 'entrepreneur'), 4),
#  (('entrepreneur', 'contributor'), 4)]

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
# YOUR CODE HERE!
token_count(bitcoin_text)
# Out:
# [('char', 98),
#  ('bitcoin', 73),
#  ('reuters', 69),
#  ('staff', 23),
#  ('photo', 19),
#  ('march', 19),
#  ('illustration', 19),
#  ('tesla', 18),
#  ('new', 18),
#  ('file', 18)]

# %%
# Get the top 10 words for Ethereum
# YOUR CODE HERE!
token_count(ethereum_text)
# Out:
# [('char', 98),
#  ('cryptocurrency', 27),
#  ('nft', 24),
#  ('digital', 23),
#  ('bitcoin', 20),
#  ('ethereum', 20),
#  ('blockchain', 18),
#  ('new', 18),
#  ('token', 18),
#  ('million', 17)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
# YOUR CODE HERE!
wc = WordCloud()
bitcoin_string = ' '.join(bitcoin_df.text)
bitcoin_word_img = wc.generate(bitcoin_string)
plt.imshow(bitcoin_word_img)

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!
ethereum_string = ' '.join(ethereum_df.text)
ethereum_word_img = wc.generate(ethereum_string)
plt.imshow(ethereum_word_img)

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
# YOUR CODE HERE!
bitcoin_string
# Out:
# 'Whether youre looking to make a larger investment or you just want to dabble in cryptocurrencies, you can purchase Bitcoin, Ethereum, Bitcoin Cash, and Litecoin through PayPal. And, soon, youll be ab… [+3818 chars] As it promised earlier this year, Tesla now accepts payment in Bitcoin, according to Tesla\'s website and a tweet from CEO Elon Musk. In a subsequent tweet, Musk said that "Bitcoin paid to Tesla will … [+1390 chars] The crypto industry as a whole has seen a momentous year of growth, heavily spurred on by the entrance of institutional investors adopting bitcoin due to its store of value properties. The 2020 spike… [+4675 chars] The inevitable has happened: You can now purchase a Tesla vehicle with Bitcoin.\xa0\r\nThis is according to Tesla CEO, pardon, Technoking Elon Musk, who tweeted it on Wednesday.\xa0\r\nYou can now buy a Tesla … [+1648 chars] Tesla made headlines earlier this year when it took out significant holdings in bitcoin, acquiring a roughly $1.5 billion stake at then-prices in early February. At the time, it also noted in an SEC … [+2071 chars] National Burrito Day lands on April Fools Day this year, but thankfully restaurants arent playing around with their deals. Starting tomorrow, restaurants like Pollo Loco and Moes Southwest Grill are … [+2882 chars] One of the strictest crackdowns worldwide\r\nPhoto by Michele Doying / The Verge\r\nIndia is reportedly moving forward with a sweeping ban on cryptocurrencies. According to Reuters, the countrys legislat… [+1656 chars] The hacker behind last years big Twitter hack\r\n has just been sentenced to hard time.\r\nGraham Ivan Clark, the teenage hacker who broke\r\n into Twitters systems, took over verified accounts, and used t… [+2552 chars] It seems like everyone is making money off of NFTs, or non-fungible tokens, those digital artworks that have been labeled the next investment mania. Everyone, that is, except for you. Its the same fe… [+5036 chars] Data centers and bitcoin mining operations are becoming huge energy hogs and the explosive growth of both risks undoing a lot of the progress that’s been made to reduce global greenhouse gas emission… [+2494 chars] A proposed law in India would make it a crime to mine, trade, or even hold cryptocurrencies like bitcoin in the country, according to a new report from Reuters citing a senior government official. It… [+1725 chars] Its been a big year for crypto, and Robinhood shared some stats today providing more evidence that the crypto boom is more than just hype — at least for now.\r\nIn a blog, Christine Brown, Robinhoods h… [+2157 chars] By Reuters Staff\r\n(Reuters) -MicroStrategy Inc, a major bitcoin corporate backer, said on Monday its non-employee directors will get fees for their services in bitcoin, instead of cash.\r\nShares of th… [+685 chars] PayPal this morning announced the launch of Checkout with Crypto, a new feature that will allow consumers to check out at millions of online businesses using cryptocurrency. The feature expands on Pa… [+3997 chars] By Reuters Staff\r\nApril 12 (Reuters) - MicroStrategy Inc, a major bitcoin corporate backer, said on Monday its non-employee directors will get fees for their services in bitcoin , instead of cash. (R… [+67 chars] Non-fungible tokens are all about taking collectibles to the digital realm, and Funko is eager to seize on that while it can. The company has bought control of the NFT startup TokenWave with an aim t… [+1138 chars] March\r\n23, 2021\r\n3 min read\r\nThis article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\r\nAfter analyzing the history of the growth Bitcoin , exp… [+2236 chars] The Wise Origin Bitcoin ETF is the latest entrant in a growing race to launch a bitcoin exchange-traded product in the United States. According to the filing, a firm called FD Funds Management LLC is… [+1081 chars] By Reuters Staff\r\nFILE PHOTO: A representation of virtual currency Bitcoin and U.S. One Dolla ...

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
bitcoin_doc = nlp(bitcoin_string)
# Add a title to the document
# YOUR CODE HERE!
bitcoin_doc.user_data['title'] = 'Bitcoin NER'

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(bitcoin_doc, style ='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Whether youre looking to make a larger investment or you just want to dabble in cryptocurrencies, you can purchase
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin, Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and Litecoin through PayPal. And, soon, youll be ab… [+3818 chars] As it promised
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     earlier this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  now accepts payment in
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , according to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's website and a tweet from CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . In a subsequent tweet,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said that &quot;Bitcoin paid to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  will … [+1390 chars] The crypto industry as a whole has seen
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a momentous year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of growth, heavily spurred on by the entrance of institutional investors adopting bitcoin due to its store of value properties. The
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  spike… [+4675 chars] The inevitable has happened: You can now purchase a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  vehicle with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>This is according to Tesla CEO, pardon, Technoking
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who tweeted it on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>You can now buy a Tesla … [+1648 chars] Tesla made headlines
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     earlier this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  when it took out significant holdings in bitcoin, acquiring a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     roughly $1.5 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  stake at then-prices in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     early February
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . At the time, it also noted in an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SEC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  … [+2071 chars]
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     National Burrito Day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  lands on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April Fools Day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , but thankfully restaurants arent playing around with their deals. Starting
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tomorrow
#     <span s

# %%
# List all Entities
# YOUR CODE HERE!
for ent in bitcoin_doc.ents:
    print(ent.text, ent.label_)
# Out:
# Bitcoin, Ethereum ORG
# Bitcoin Cash PERSON
# earlier this year DATE
# Tesla ORG
# Bitcoin PERSON
# Tesla ORG
# Elon Musk PERSON
# Musk PERSON
# Tesla ORG
# a momentous year DATE
# 2020 DATE
# Tesla ORG
# Bitcoin PERSON
# Elon Musk PERSON
# Wednesday DATE
# earlier this year DATE
# roughly $1.5 billion MONEY
# early February DATE
# SEC ORG
# National Burrito Day EVENT
# April Fools Day DATE
# this year DATE
# tomorrow DATE
# Pollo Loco FAC
# Photo PERSON
# Michele Doying PERSON
# India GPE
# Reuters ORG
# last years DATE
# Twitter PRODUCT
# Graham Ivan Clark PERSON
# Twitters NORP
# India GPE
# Reuters ORG
# a big year DATE
# Robinhood ORG
# today DATE
# Christine Brown PERSON
# Robinhoods PERSON
# Reuters ORG
# Reuters ORG
# Inc PERSON
# Monday DATE
# this morning TIME
# millions CARDINAL
# Reuters ORG
# April 12 DATE
# Reuters ORG
# Monday DATE
# Funko PERSON
# NFT ORG
# TokenWave ORG
# 23, 2021 DATE
# Spanish NORP
# AI ORG
# Bitcoin PERSON
# The Wise Origin Bitcoin ETF WORK_OF_ART
# the United States GPE
# FD Funds Management LLC ORG
# Reuters ORG
# Bitcoin PERSON
# U.S. GPE
# January 8, 2021 DATE
# Dado Ru PERSON
# Reuters ORG
# Bitcoin PERSON
# U.S. GPE
# January 27, 2020 DATE
# Reuters ORG
# LONDON GPE
# April 13 DATE
# Reuters ORG
# 62,575 MONEY
# Tuesday DATE
# 2021 DATE
# Reuters ORG
# Bitcoin PERSON
# March 15, 2021 DATE
# PayPal PERSON
# Julian Satterthwaite PERSON
# another week DATE
# March 26 DATE
# the Wall Street Journal ORG
# the Commodity Futures Trading Commission ORG
# Coinbase ORG
# $6.5 million MONEY
# Reuters ORG
# Bitcoin PERSON
# March 15, 2021 DATE
# Reuters ORG
# 1 CARDINAL
# The Fine Print: WORK_OF_ART
# Entrepreneur ORG
# Last year DATE
# the Great Depression EVENT
# first ORDINAL
# NFT ORG
# Ethereum ORG
# more than $224 million MONEY
# 2021 DATE
# OpenSea NORP
# the first quarter of 2021 DATE
# American NORP
# Coinbase NORP
# Coinbase ORG
# New White House Communications ORG
# Anthony Scaramucci PERSON
# daily DATE
# the White House FAC
# Washington GPE
# U.S. GPE
# July 21, 2017 DATE
# Jonathan Ernst ORG
# NEW YORK GPE
# Reu PERSON
# Apple ORG
# Robbed Blind PERSON
# Last month DATE
# Phillipe Christodoulou PERSON
# Reuters ORG
# Bitcoin PERSON
# March 15, 2021 DATE
# WASHINGTON GPE
# Reuters ORG
# Dec. 8, 2017 DATE
# Benoit Tessier/File Photo
#  ORG
# LONDON GPE
# Reuters ORG
# Elon Musk PERSON
# Tesla PERSON
# Reuters ORG
# March 24 DATE
# Reuters ORG
# Wednesday DATE
# Reuters ORG
# Bitcoin PERSON
# March 15, 2021 DATE
# Reuters ORG
# Reuters ORG
# April 6 DATE
# Reuters ORG
# Hindenburg Research ORG
# Tuesday DATE
# Chinese NORP
# Ebang International Holdings Inc. ORG
# Ebang PERSON
# Reuters ORG
# LONDON GPE
# March 29 DATE
# Reuters ORG
# one-week DATE
# Monday DATE
# as much as 4.5% PERCENT
# 58,300 MONEY
# above $61,000 MONEY
# earlier this month DATE
# Visa Inc PERSON
# Reuters ORG
# Morgan Stanley ORG
# San Diego GPE
# California GPE
# Sept. 24, 2013 DATE
# Mike Blake
#  PERSON
# Reuters ORG
# LONDON GPE
# Reuters ORG
# SkyBridge Capital ORG
# Anthony Scaramucci PERSON
# Wednesday DATE
# first ORDINAL
# two month DATE
# Reuters ORG
# FILE PERSON
# Tesla Inc ORG
# Elon Musk PERSON
# China GPE
# Model 3 PRODUCT
# Shanghai GPE
# China GPE
# January 7, 2020 DATE
# Aly Song/File ORG
# Reuters ORG
# Dec. 8, 2017 DATE
# Benoit Tessier/Illustration/File Photo ORG
# Reuters ORG
# ZURICH PERSON
# Reuters ORG
# The Swiss Financial Market Supervisory Authority ORG
# FINMA ORG
# Zug PERSON
# Bitcoin Suisse AG ORG
# 2019 DATE
# Reuters ORG
# ZURICH GPE
# March 17 DATE
# Reuters ORG
# The Swiss Financial Market Supervisory Authority ORG
# FINMA ORG
# Zug PERSON
# Bitcoin Suisse AG ORG
# 2019 DATE
# Reuters ORG
# around $60,000 MONEY
# Monday DATE
# U.S. GPE
# LONDON GPE
# Reuters ORG
# MicroStrategy Inc ORG
# Reuters ORG
# Reuters ORG
# Montana GPE
# Carolinas GPE
# New York City GPE
# ATM ORG
# more than 4% PERCENT
# Wednesday DATE
# 60,000 MONEY
# Sellers PERSON
# 60,000 MONEY
# March 31 DATE
# CoinShares ORG
# Azeem Azhar PERSON
# Bitcoin PERSON
# March 15 DATE
# Reuters ORG
# Montana GPE
# Carolinas GPE
# New York City GPE
# ATM ORG
# First ORDINAL
# thousands CARDINAL
# MarketBeatAs PERSON
# Bitcoin’s ORG
# the past year DATE
# Bitcoin PERSON
# Apple ORG
# 12 CARDINAL
# French NORP
# Reuters ORG
# FILE PERSON
# Goldman Sachs ORG
# the New York Stock Exchange ORG
# NYSE ORG
# New York GPE
# U.S. GPE
# April 17, 2018 DATE
# Brendan McDe PERSON
# The US Department of Justice ORG
# Canada GPE
# LONDON GPE
# Reuters ORG
# billions of dollars MONEY
# $4 trillion MONEY
# Wednesday DATE
# three CARDINAL
# Chipotle Mexican Grill PERSON
# NYSE ORG
# CMG ORG
# 100,000 MONEY
# 100,000 MONEY
# National Burrito Day ORG
# April 1 DATE
# Reuters ORG
# Reuters ORG
# Hindenburg Research ORG
# Tuesday DATE
# Ebang International Holdings Inc ORG
# Chinese NORP
# Reuters ORG
# $1.5 billion MONEY
# Elon Musk PERSON
# today DATE
# 22, 2021 DATE
# Bitcoin PERSON
# American Airlines ORG
# U.S. GPE
# above $60,000 MONEY
# first ORDINAL
# March DATE
# Saturday DATE
# Sunday DATE
# 59.604.06 MONEY
# 24, 2021 DATE
# Spanish NORP
# AI ORG
# Elon Musk PERSON
# a few weeks ago DATE
# Spanish NORP
# AI ORG
# Entrepreneur ORG
# the summer DATE
# Entrepreneur ORG
# Bitcoin PERSON
# LONDON GPE
# Reuters ORG
# LONDON GPE
# March 2 DATE
# HSBC InvestDirect ORG
# MicroStrategy ORG
# LONDON GPE
# Reuters ORG
# later on DATE
# Tuesday DATE
# U.S. GPE
# millions CARDINAL
# Tuesday DATE
# Katie Stockton PERSON
# Stockton PERSON
# Reuters ORG
# Litecoin PERSON
# February 14, 2018 DATE
# REUTERS/Dad ORG
# Bitcoin PERSON
# $2 trillion MONEY
# first ORDINAL
# earlier this week DATE
# Bitcoin  PERSON
# Reuters ORG
# Bitcoin PERSON
# April 24, 2020 DATE
# WASHINGTON GPE
# 24, 2021 DATE
# Entrepreneur ORG
# Bitcoin PERSON
# 22, 2021 DATE
# MarketBeat
#  MONEY
# 2021 DATE
# Stephen Kelso PERSON
# London GPE
# 36.32 MONEY
# April 3 DATE
# 90% PERCENT
# 17, 2021 DATE
# Jeffrey Sachs PERSON
# last Sunday DATE
# Bitcoin PERSON
# Alma Mater Europa PERSON
# 30, 2021 DATE
# Visa PERSON
# PayPal PERSON
# Reuters ORG
# Visa ORG
# yesterday DATE
# BlackRock ORG
# 360,000 MONEY
# January DATE
# Wednesday DATE
# the Securities and Exchange Commission ORG
# Two CARDINAL
# Elon Musk PERSON
# Joe Rogan's PERSON
# 13 CARDINAL
# 13 CARDINAL
# Tesla PERSON
# Elon Musk PERSON
# LONDON GPE
# Reuters ORG
# Britain GPE
# UK GPE
# John G PERSON
# Reuters ORG
# FILE PERSON
# January 29, 2021 DATE
# REUTERS ORG
# Brendan McDermid/Illustration PERSON
# Reuters ORG
# Robinhood ORG
# Checkout CARDINAL
# US GPE
# the next few months DATE
# first ORDINAL
# about $571 million MONEY
# more than 22,000 CARDINAL
# Com PERSON
# ASIC ORG
# Rockdale GPE
# Texas GPE
# Riot Blockchain PERSON
# Riot Blockchain PERSON
# North American NORP
# Whi PERSON
# NurPhoto ORG
# Getty Images ORG
# Goldman Sachs ORG
# CNBC ORG
# Wednesday DATE
# Norwegian NORP
# Rokke ORG
# $6 billion MONEY
# Aker ASA ORG
# Dado Ruvic PERSON
# Reuters ORG
# $2 trillion MONEY
# Monday DATE
# the Thomson Reuters Regulatory Intelligence ORG
# Morgan Stanley ORG
# Wealth Management ORG
# JMP ORG
# Wednesday DATE
# Morgan Stanley ORG
# Elon Musk PERSON
# this morning TIME
# Tesla ORG
# Elon Musk PERSON
# Last week DATE
# Elon Musk PERSON
# $25 billion MONEY
# one day DATE
# Monday DATE
# NFT ORG
# recent weeks DATE
# 2018 DATE
# BTC ORG
# around $20,000 MONEY
# less than $6,000 MONEY
# today DATE

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the ethereum text together
# YOUR CODE HERE!
ethereum_string
# Out:
# 'One of the strictest crackdowns worldwide\r\nPhoto by Michele Doying / The Verge\r\nIndia is reportedly moving forward with a sweeping ban on cryptocurrencies. According to Reuters, the countrys legislat… [+1656 chars] Whether youre looking to make a larger investment or you just want to dabble in cryptocurrencies, you can purchase Bitcoin, Ethereum, Bitcoin Cash, and Litecoin through PayPal. And, soon, youll be ab… [+3818 chars] Famed auction house Christies just sold its first purely digital piece of art for a whopping $69 million. For that price, the buyer got a digital file of a collage of 5,000 images and a complex legac… [+12891 chars] Payment card network Visa has announced that transactions can be settled using USD Coin (USDC), a stablecoin powered by the Ethereum blockchain. Crypto.com is the first company to test the new capabi… [+2187 chars] ConsenSys, a key player in crypto and a major proponent of the Ethereum blockchain, has raised a\xa0$65 million funding round from\xa0J.P. Morgan, Mastercard, and UBS AG, as well as major blockchain compan… [+8767 chars] Move fast, break things, get hacked.\r\nThat’s what happened at Roll, the social currency platform that allows creators to mint and distribute their own Ethereum-based cryptocurrency known as social to… [+3813 chars] The NFT craze has been an intriguing moment for digital artists who have seen seen great leaps in how tech has allowed them to create their work, but not as much progress in shifting how they profit … [+2603 chars] Here\'s everything you need to know about non-fungible tokens, the latest cryptocurrency craze.\r\nRead the full story here. (And learn even more about NFTs here.) OpenSea has been one of a handful of NFT marketplaces to explode in popularity in recent weeks as collectors wade into the trading of non-fungible tokens on the blockchain. While new startups have be… [+2529 chars] MetaMask, one of the most popular web wallets for cryptocurrency platform Ethereum, went mobile on iOS and Android in September 2020. However, the mobile version wasn\'t updated at the same pace as th… [+1807 chars] A security breach at cryptocurrency platform Roll allowed a hacker to obtain the private key to its hot wallet and steal its contents worth about $5.7 million.\r\nIn a statement, the company said it wa… [+1908 chars] Its been a big year for crypto, and Robinhood shared some stats today providing more evidence that the crypto boom is more than just hype — at least for now.\r\nIn a blog, Christine Brown, Robinhoods h… [+2157 chars] March\r\n26, 2021\r\n1 min read\r\nThis article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\r\nThe iconic New York Times daily auctioned a newspaper a… [+639 chars] Non-fungible tokens (NFTs) are quickly becoming go-tos for digital collecting, and that now includes something you might have had as a kid: baseball cards. Topps is launching its first NFT-based base… [+1535 chars] TL;DR: The QuantInsti: Quantitative Trading for Beginners Bundle is on sale for £36.32 as of April 3, saving you 90% on list price.\r\nWhether you\'re purchasing drinks at the bar or managing your finan… [+2288 chars] Ether spiked as much as 8% on Tuesday to a new record high ahead of Coinbase\'s direct listing and Berlin hard fork, the next upcoming upgrade to the ethereum network, both happening on April 14.\r\nEth… [+1831 chars] Last month, hours before news of Beeple’s $69 million NFT sale grabbed the front pages of newspapers across the country, a pair of 24 x 24 pixel portraits of aliens wearing little hats sold separatel… [+16687 chars] The MLB has its answer to the NBAs Top Shot NFT clips\r\nMajor League Baseball has announced its latest move to cash in on the NFT craze: official blockchain-based versions of classic Topps baseball ca… [+2436 chars] A proposed law in India would make it a crime to mine, trade, or even hold cryptocurrencies like bitcoin in the country, according to a new report ...

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
ethereum_doc = nlp(ethereum_string)
# Add a title to the document
# YOUR CODE HERE!
ethereum_doc.user_data['title'] = 'Ethereum NER'

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(ethereum_doc, style = 'ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Photo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michele Doying
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is reportedly moving forward with a sweeping ban on cryptocurrencies. According to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the countrys legislat… [+1656 chars] Whether youre looking to make a larger investment or you just want to dabble in cryptocurrencies, you can purchase
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin, Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and Litecoin through PayPal. And, soon, youll be ab… [+3818 chars] Famed auction house
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  just sold its
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  purely digital piece of art for a whopping
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $69 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . For that price, the buyer got a digital file of a collage of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  images and a complex legac… [+12891 chars] Payment card network
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Visa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has announced that transactions can be settled using
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USD Coin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (USDC), a stablecoin powered by the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  blockchain.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crypto.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  company to test the new capabi… [+2187 chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ConsenSys
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a key player in crypto and a major proponent of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  blockchain, has raised a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $65 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  funding round from
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     J.P. Morgan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mastercard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UBS AG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>That’s what happened at Roll, the social currency platform that allows creators to mint and distribute their own
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; ma

# %%
# List all Entities
# YOUR CODE HERE!
for ent in ethereum_doc.ents:
    print(ent.text, ent.label_)
# Out:
# One CARDINAL
# Photo PERSON
# Michele Doying PERSON
# India GPE
# Reuters ORG
# Bitcoin, Ethereum ORG
# Bitcoin Cash PERSON
# Christies ORG
# first ORDINAL
# $69 million MONEY
# 5,000 CARDINAL
# Visa ORG
# USD Coin ORG
# Ethereum ORG
# Crypto.com ORG
# first ORDINAL
# ConsenSys ORG
# Ethereum ORG
# $65 million MONEY
# J.P. Morgan PERSON
# Mastercard PERSON
# UBS AG ORG
# Ethereum ORG
# NFT ORG
# NFT ORG
# recent weeks DATE
# MetaMask PRODUCT
# one CARDINAL
# Ethereum ORG
# September 2020 DATE
# about $5.7 million MONEY
# a big year DATE
# Robinhood ORG
# today DATE
# Christine Brown PERSON
# Robinhoods PERSON
# 26, 2021 DATE
# Spanish NORP
# AI ORG
# New York Times ORG
# daily DATE
# Topps GPE
# first ORDINAL
# NFT ORG
# 36.32 MONEY
# April 3 DATE
# 90% PERCENT
# as much as 8% PERCENT
# Tuesday DATE
# Coinbase ORG
# Berlin GPE
# April 14 DATE
# Last month DATE
# hours TIME
# Beeple’s ORG
# $69 million MONEY
# NFT ORG
# 24 CARDINAL
# 24 CARDINAL
# MLB ORG
# NFT ORG
# Major League Baseball ORG
# NFT ORG
# Topps GPE
# India GPE
# Reuters ORG
# Damien Hirst PERSON
# Chris Young PERSON
# Superstar PERSON
# Damien Hirst PERSON
# Ethereum ORG
# Dado Ruvic PERSON
# Reuters ORG
# Friday DATE
# 60,000.</li MONEY
# Apple ORG
# Amazon ORG
# iPad ORG
# Leon PRODUCT
# more than $2 million MONEY
# Getty Images PERSON
# Reuters ORG
# Monday DATE
# Reuters ORG
# Monday DATE
# Digital ORG
# Grayscale Investments ORG
# Wednesday DATE
# five CARDINAL
# 13 CARDINAL
# Entrepreneur ORG
# Decentralized PERSON
# 2020s DATE
# Last year's DATE
# March 29 DATE
# Reuters ORG
# Monday DATE
# Two CARDINAL
# Ethereum PERSON
# four CARDINAL
# Japanese NORP
# Bitcoin PERSON
# $2 trillion MONEY
# first ORDINAL
# earlier this week DATE
# Bitcoin  PERSON
# these days DATE
# NFT ORG
# this morning TIME
# millions CARDINAL
# 30, 2021 DATE
# Visa PERSON
# PayPal PERSON
# Reuters ORG
# Visa ORG
# yesterday DATE
# C++ NORP
# NFT ORG
# Ethereum ORG
# two CARDINAL
# Entrepreneur ORG
# Bitcoin PERSON
# Annabelle Huang's PERSON
# 2017 DATE
# first ORDINAL
# Deutsche Bank ORG
# Nomura ORG
# New Y GPE
# Checkout CARDINAL
# US GPE
# the next few months DATE
# first ORDINAL
# 19, 2021 DATE
# Entrepreneur ORG
# Enjin GPE
# $18.9 million MONEY
# first ORDINAL
# NFT ORG
# Polkadot GPE
# NFT ORG
# 1990 DATE
# millions of dollars MONEY
# Alex Ramirez-Mallis PERSON
# 36 DATE
# The Post ORG
# NFT ORG
# NFT ORG
# One Calendar Year of Record WORK_OF_ART
# above $2,700 MONEY
# Kraken ORG
# Kraken ORG
# Pete Humiston PERSON
# Elon Musks PERSON
# NFT ORG
# over one million dollars MONEY
# 35% PERCENT
# March DATE
# Kraken ORG
# Dado Ruvic PERSON
# Reuters ORG
# above $2,700 MONEY
# NFT ORG
# Ethereum ORG
# Ethereum ORG
# Token PERSON
# 6 CARDINAL
# 6 CARDINAL
# 2017 DATE
# Visa ORG
# James Martin PERSON
# CNET ORG
# Monday DATE
# March 19 DATE
# Reu NORP
# Reuters ORG
# April 13 DATE
# Reuters ORG
# ConsenSys ORG
# Tuesday DATE
# $65 million MONEY
# J.P. Morgan PERSON
# Mastercard PERSON
# NFT ORG
# Ethereum ORG
# more than $224 million MONEY
# 2021 DATE
# OpenSea NORP
# NFT ORG
# these days DATE
# Pussy Riot PERSON
# Nadya Tolokonnikova PERSON
# one CARDINAL
# 13, 2021 DATE
# Entrepreneur ORG
# A century ago DATE
# French NORP
# Marcel Duchamp PERSON
# 1917 DATE
# 31, 2021 DATE
# Spanish NORP
# AI ORG
# more than 4% PERCENT
# Wednesday DATE
# 60,000 MONEY
# Sellers PERSON
# 60,000 MONEY
# 6 CARDINAL
# 5 CARDINAL
# NFT ORG
# 3D ORG
# 18,000 MONEY
# last month DATE
# this month DATE
# as much as 70% PERCENT
# February DATE
# Bloomberg GPE
# 13, 2021 DATE
# Super Bowl EVENT
# the Tampa Bay Buccaneers ORG
# Rob Gronkowski PERSON
# NFT ORG
# Reuters ORG
# this year DATE
# NFT ORG
# millions of dollars MONEY
# Leon GPE
# Love WORK_OF_ART
# night TIME
# --Matt Groening PERSON
# U.S. GPE
# Fed ORG
# Updates GPE
# U.S. GPE
# afternoon TIME
# NEW YORK GPE
# April 6 DATE
# Reuters ORG
# U.S. GPE
# two-week DATE
# NEW YORK GPE
# Reuters ORG
# a record $4.5 billion MONEY
# the first quarter DATE
# two CARDINAL
# Tuesday DATE
# NFT ORG
# Tesla ORG
# Google ORG
# Bitcoin PERSON
# first ORDINAL
# second ORDINAL
# Friday DATE
# above $2,000 MONEY
# +4.12% PERCENT
# nearly 7% PERCENT
# around $2,069 MONEY
# $100 billion MONEY
# New Constructs ORG
# David Trainer PERSON
# one CARDINAL
# hundreds of millions of dollars MONEY
# LONDON GPE
# Reuters ORG
# SkyBridge Capital ORG
# Anthony Scaramucci PERSON
# Wednesday DATE
# NFT ORG
# Oleksandra Troian PERSON
# recent weeks DATE
# 0 CARDINAL
# nearly 10 years DATE
# Ars Technica PERSON
# first ORDINAL
# first ORDINAL
# Last month DATE
# Tom Kuennen PERSON
# Ontario GPE
# 500 MONEY
# Elon Musk-themed PERSON
# Moon Ticket PERSON
# DarpaLabs NORP
# Emily Segal PERSON
# Burn Alpha FAC
# Mirror ORG
# 0.1 CARDINAL
# ETH ORG
# yesterday DATE
# evening TIME
# 25 CARDINAL
# ETH ORG
# GPU ORG
# the last several months DATE
# Chinese NORP
# TVP News ORG
# the Hong Kong Customs ORG
# Excise PERSON
# Bank of America ORG
# DeFi ORG
# Leon PRODUCT
# more than $2 million MONEY
# Getty Images PERSON
# last Monday DATE
# 40,671 CARDINAL
# first ORDINAL
# $69 million MONEY
# GeForce ORG
# 3060 DATE
# last month DATE
# GPU ORG
# March 26, 2021 DATE
# 8:04 a.m. TIME
# March 26, 2021 DATE
# 8:04 a.m. TIME
# 2019 DATE
# GeForce ORG
# 3060 DATE
# Ethereum ORG
# NVIDIA ORG
# DOOM  PERSON
# NFT ORG
# this week DATE
# Yesterday DATE
# one CARDINAL
# March DATE
# Kenny Schachter PERSON
# Visa ORG
# Monday DATE
# S!NG PRODUCT
# iPhone ORG
# iPad ORG
# NFT ORG
# about $240 billion MONEY
# second ORDINAL
# ETH ORG
# Apple ORG
# iPhone ORG
# Phillipe Christodoulou 17.1 ORG
# 600 MONEY
# the last 6 months DATE
# last month DATE
# Dapper, Flow ORG
# NBA Top Shot PERSON
# Goldman Sachs ORG
# ConsenSys ORG
# Ethereum ORG
# $65 million MONEY
# J.P. Morgan PERSON
# Mastercard PERSON
# UBS AG ORG
# MarketBeatAs PERSON
# Bitcoin’s ORG
# the past year DATE
# Bitcoin PERSON
# 30, 2021 DATE
# MarketBeatToday DATE
# Tomorrow DATE
# NASDAQ Bell PERSON
# NASDAQ ORG
